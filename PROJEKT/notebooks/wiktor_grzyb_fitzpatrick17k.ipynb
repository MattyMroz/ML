# %% [markdown]
# # Fitzpatrick17k — klasyfikacja chorób skóry z uwzględnieniem typu skóry
#
# **Autor:** Wiktor Grzyb
# **Zbiór:** Fitzpatrick17k, 16 577 obrazów, 114 chorób × 6 typów skóry Fitzpatrick'a
#
# ## 🚧 Stub do uzupełnienia
#
# Ten notebook to szablon — osoba 3 (Wiktor) uzupełnia go własnym pipelinem.
#
# ### Sugerowany plan (do dopracowania):
#
# 1. **Setup** — imports, wczytanie `fitzpatrick17k.csv`
# 2. **Eksploracja danych** — rozkład chorób, rozkład typów skóry Fitzpatrick'a, crosstab choroba × typ skóry
# 3. **Agregacja klas** — z 114 chorób do 3 kategorii (benign / malignant / non-neoplastic) — zgodnie z `three_partition_label` w CSV
# 4. **Preprocessing** — resize, augmentacja
# 5. **Model** — transfer learning (ResNet50 / VGG16)
# 6. **Ewaluacja z uwzględnieniem fairness**:
#    - accuracy, macro-F1 overall
#    - **accuracy per typ skóry** (1–6) → test na bias modelu
#    - macro-F1 per typ skóry
# 7. **Interpretacja** — porównanie wyników między typami skóry (kluczowe dla tego zbioru)
# 8. **Porównanie z literaturą** — Groh et al. 2021 (oryginalna praca)
# 9. **Zapis wyników** do `../results/wiktor_grzyb_fitzpatrick17k_final.csv`
#
# ### Źródło danych
#
# Instrukcja pobrania w `../data/fitzpatrick17k/README.md`.
#
# ### Literatura do przejrzenia
#
# - Groh et al. 2021, *CVPR Workshop* — oryginalna praca o zbiorze, ResNet18 baseline
# - Daneshjou et al. 2022, *Science Advances* — bias w AI dermatologicznym (Fitzpatrick jako punkt odniesienia)
# - Kinyanjui et al. 2020 — fairness w dermatologii

# %%
# TODO: imports
from pathlib import Path

DATA_DIR = Path("../data/fitzpatrick17k")
print("Dataset path:", DATA_DIR.resolve())
print("Exists:", DATA_DIR.exists())
